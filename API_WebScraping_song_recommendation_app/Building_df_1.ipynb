# %%
import config

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

import pandas as pd
import numpy as np

# %%
spotify = spotipy.Spotify(requests_timeout=5)

# %%
#Searching a playlist
playlist = sp.user_playlist_tracks("spotify", "5iqZs4HHMnJuVOaT6uYGrW",market="DE")
#print(playlist["items"][0])
playlist["items"][0]



#Extracting the songs of a playlist
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="DE")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks


tracks=get_playlist_tracks("spotify", "5iqZs4HHMnJuVOaT6uYGrW")
print(len(tracks))

#до этого работает норм, дальше надо делить дф чтоб не висло

'''
#extracting songs features
list_of_audio_features=[]
for item in range(len(tracks)):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])
'''
# Out:
# 10000
# '\n#extracting songs features\nlist_of_audio_features=[]\nfor item in range(len(tracks)):\n    #print (tracks[item]["track"]["id"])\n    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])\n'

# %%
#tracks=get_playlist_tracks("spotify", "1TdTz1c9jp0fB4s4ZRgtV3")
print(len(tracks))
#tracks

#split df
tracks1 = tracks[:1500]
tracks2 = tracks[1501:3000]
tracks3 = tracks[3001:4500]
#tracks4 = tracks[4501:6000]
#tracks5 = tracks[6001:7500]
#tracks6 = tracks[7501:9000]
#tracks7 = tracks[9001:10012]

len(tracks1)
# Out:
# 10000
# 1500

# %%
#extracting songs features
#запускать по одному для каждого дф
list_of_audio_features2=[]
for item in range(len(tracks2)):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features2.append(sp.audio_features(tracks2[item]["track"]["id"])[0])

# %%
#здесь функция для небольших фреймов
'''
#Searching a playlist
playlist = sp.user_playlist_tracks("spotify", "1TdTz1c9jp0fB4s4ZRgtV3",market="DE")
#print(playlist["items"][0])

#Extracting the songs of a playlist
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="DE")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks


tracks=get_playlist_tracks("spotify", "1TdTz1c9jp0fB4s4ZRgtV3")
print(len(tracks))

#extracting songs features
list_of_audio_features=[]
for item in range(len(tracks)):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])
'''
# Out:
# '\n#Searching a playlist\nplaylist = sp.user_playlist_tracks("spotify", "1TdTz1c9jp0fB4s4ZRgtV3",market="DE")\n#print(playlist["items"][0])\n\n#Extracting the songs of a playlist\ndef get_playlist_tracks(username, playlist_id):\n    results = sp.user_playlist_tracks(username,playlist_id,market="DE")\n    tracks = results[\'items\']\n    while results[\'next\']:\n        results = sp.next(results)\n        tracks.extend(results[\'items\'])\n    return tracks\n\n\ntracks=get_playlist_tracks("spotify", "1TdTz1c9jp0fB4s4ZRgtV3")\nprint(len(tracks))\n\n#extracting songs features\nlist_of_audio_features=[]\nfor item in range(len(tracks)):\n    #print (tracks[item]["track"]["id"])\n    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])\n'

# %%
data = [i for i in list_of_audio_features2 if i is not None]

# should work now
df_tonextstep = pd.DataFrame(data)

# %%
#Creating df for particular playlists
df_hip2=pd.DataFrame(df_tonextstep)    
df_hip2=df_hip2[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

#Записанные дф
#df_ch1
#df_pop1
#df_pop2
#df_pop3
#df_dance90
#df_el1
#df_el2
#df_rock1
#df_rock2
#df_rock3
#df_hip1 
#df_hip2 
#df_clas


#ДАЛЬШЕ ЗАПИСЫВАЕМ ОСТАЛЬНЫЕ И КОНКАТИМ, щас запишу в цсв что есть

df_hip2.to_csv('df_hip2.csv')

# %%
df_opencheck = pd.read_csv('df_hip2.csv')
df_opencheck
# Out:
#       Unnamed: 0  danceability  energy  loudness  speechiness  acousticness  \
# 0              0         0.625  0.0724   -17.968       0.0364        0.3510
# 1              1         0.797  0.1740   -12.892       0.2790        0.8950
# 2              2         0.796  0.0658   -12.499       0.6150        0.8040
# 3              3         0.644  0.2680    -9.653       0.0632        0.6720
# 4              4         0.740  0.4050   -12.181       0.0854        0.8910
# ...          ...           ...     ...       ...          ...           ...
# 1493        1493         0.728  0.6150    -6.100       0.0329        0.0345
# 1494        1494         0.617  0.7530    -7.512       0.2290        0.2420
# 1495        1495         0.693  0.6990    -7.688       0.0532        0.0175
# 1496        1496         0.850  0.5280    -7.643       0.0630        0.2140
# 1497        1497         0.680  0.9370    -7.521       0.1790        0.2750
#
# ...

# %%
#concat dfs
#df_last=pd.concat([df1,df], sort=False, axis=1, ignore_index=True)
#df_last

# %%
df_ch1 = pd.read_csv("df_ch1.csv")
df_pop1 = pd.read_csv("df_pop1.csv")
df_pop2 = pd.read_csv("df_pop2.csv")
df_pop3 = pd.read_csv("df_pop3.csv")
df_dance90 = pd.read_csv("df_dance90.csv")
df_el1 = pd.read_csv("df_el1.csv")
df_el2 = pd.read_csv("df_el2.csv")
df_rock1 = pd.read_csv("df_rock1.csv")
df_rock2 = pd.read_csv("df_rock2.csv")
df_rock3 = pd.read_csv("df_rock3.csv")
df_hip1 = pd.read_csv("df_hip1.csv")
df_hip2 = pd.read_csv("df_hip2.csv")
df_clas = pd.read_csv("df_clas.csv")



df_clas
# Out:
#      Unnamed: 0  danceability  energy  loudness  speechiness  acousticness  \
# 0             0         0.374  0.1350   -18.536       0.0490         0.790
# 1             1         0.214  0.0559   -28.155       0.0436         0.904
# 2             2         0.394  0.0981   -18.648       0.0384         0.661
# 3             3         0.334  0.2380   -17.718       0.0470         0.764
# 4             4         0.168  0.0523   -28.216       0.0446         0.775
# ..          ...           ...     ...       ...          ...           ...
# 686         686         0.453  0.1860   -19.654       0.0517         0.969
# 687         687         0.411  0.1360   -17.444       0.0436         0.981
# 688         688         0.387  0.0194   -26.500       0.0436         0.963
# 689         689         0.219  0.0356   -21.204       0.0476         0.975
# 690         690         0.406  0.1520   -19.834       0.0426         0.982
#
# ...

# %%
def load_original_data():
    df_ch1 
    df_pop1
    df_pop2
    df_pop3
    df_dance90
    df_el1
    df_el2
    df_rock1
    df_rock2
    df_rock3
    df_hip1
    df_hip2
    df_clas
    return pd.concat([df_ch1,df_pop1,df_pop2,df_pop3,df_dance90,df_el1,df_el2,df_rock1,df_rock2,df_rock3,df_hip1,df_hip2,df_clas], axis=0)

df_toml = load_original_data()
df_toml
df_toml.to_csv('df_toml.csv')
